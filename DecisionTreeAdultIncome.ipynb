# %%
# -----------------------------------------------------------------
# Decision Tree Classifier
# Predict the income of an adult based on the census data
# -----------------------------------------------------------------

# Import libraries
import pandas as pd

# %%
# Read dataset
data = pd.read_csv(r'C:\Users\o.resulov\Desktop\QSS\decisiontreeAdultIncome.csv')
data
# Out:
#        age        wc      education  marital status    race   gender  \
# 0       38   Private        HS-grad        Divorced   White     Male
# 1       28   Private      Bachelors         Married   Black   Female
# 2       37   Private        Masters         Married   White   Female
# 3       31   Private        Masters   Never-married   White   Female
# 4       42   Private      Bachelors         Married   White     Male
# ...    ...       ...            ...             ...     ...      ...
# 19782   53   Private        Masters         Married   White     Male
# 19783   22   Private   Some-college   Never-married   White     Male
# 19784   40   Private        HS-grad         Married   White     Male
# 19785   58   Private        HS-grad         Widowed   White   Female
# 19786   22   Private        HS-grad   Never-married   White     Male
#
#        hours per week IncomeClass
# 0                  40       <=50K
# 1                  40       <=50K
# ...

# %%
# Check for Null values
data.isnull().sum(axis=0)
# Out:
# age               0
# wc                0
# education         0
# marital status    0
# race              0
# gender            0
# hours per week    0
# IncomeClass       0
# dtype: int64

# %%
# Create Dummy variables
data.dtypes
data = pd.get_dummies(data, drop_first=True)
data
# Out:
#        age  hours per week  wc_ Local-gov  wc_ Never-worked  wc_ Private  \
# 0       38              40              0                 0            1
# 1       28              40              0                 0            1
# 2       37              40              0                 0            1
# 3       31              50              0                 0            1
# 4       42              40              0                 0            1
# ...    ...             ...            ...               ...          ...
# 19782   53              40              0                 0            1
# 19783   22              40              0                 0            1
# 19784   40              40              0                 0            1
# 19785   58              40              0                 0            1
# 19786   22              20              0                 0            1
#
#        education_ Doctorate  education_ HS-grad  education_ Masters  \
# ...

# %%
# Create X and Y Variables
data.columns
y=data['IncomeClass_ >50K']
X=data.drop(['IncomeClass_ >50K'], axis=1)
X
# Out:
#        age  hours per week  wc_ Local-gov  wc_ Never-worked  wc_ Private  \
# 0       38              40              0                 0            1
# 1       28              40              0                 0            1
# 2       37              40              0                 0            1
# 3       31              50              0                 0            1
# 4       42              40              0                 0            1
# ...    ...             ...            ...               ...          ...
# 19782   53              40              0                 0            1
# 19783   22              40              0                 0            1
# 19784   40              40              0                 0            1
# 19785   58              40              0                 0            1
# 19786   22              20              0                 0            1
#
#        education_ Doctorate  education_ HS-grad  education_ Masters  \
# ...

# %%
# Split the X and Y dataset into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, stratify=y)

# %%
# Import and train classifier
from sklearn import tree
model = tree.DecisionTreeClassifier(criterion='entropy')
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
# Test the model
model_estimation = model.predict(X_train)
model_estimation
# Out:
# array([0, 0, 1, ..., 0, 1, 0], dtype=uint8)

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_train, model_estimation)
f1 = accuracy_score(y_train, model_estimation)

# %%
cm
# Out:
# array([[9847,  355],
#        [ 890, 2758]], dtype=int64)

# %%
f1
# Out:
# 0.9101083032490975
